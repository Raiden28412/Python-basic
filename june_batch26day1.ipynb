# %% [markdown]
# <a href="https://colab.research.google.com/github/Raiden28412/Python-basic/blob/main/june_batch26day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# output function comments
print("hello world") #This is a python program to print hello world
print()
# Out:
# hello world

# %% [markdown]
# *This is a python program to print your name *

# %%
print("Rohan") #program to print your name
# Out:
# Rohan

# %%
print("hello \nworld") #\n is used to go to the next line
# Out:
# hello
# world

# %% [markdown]
# ASCII

# %%
#ascii
#ord() used to find the ascii value
print(ord("a"))
# Out:
# 97

# %%
#chr() to find the corresponding character for ascii value
print(chr(97))
# Out:
# a

# %% [markdown]
# **Basic Data types in python**

# %%
#1.Integer- eg:2,4
#2.string- "apple","rohan"
#3.float- 2.3,5.666
#4.boolean-to store true or false
# 5.none- nothing to return

# %% [markdown]
# Variables

# %%
name="apple" #to store value "apple" to name
print(name)
print(type(name)) #to find the data type #type convertion
age=21
print(age)
print(type(age))#to find the data type # type convertion
#this method of machine finding the data type is called type convertion
#mannually changing the data type is called Type casting
ages=32
ages=str(ages)#type casting
print(ages)
print(type(ages))
height=123.44
print(height)
print(type(height))
ismarried=False
print(ismarried)
print(type(ismarried))#type covertion
a=None
print(a)
print(type(a))#type convertion
# Out:
# apple
# <class 'str'>
# 21
# <class 'int'>
# 32
# <class 'str'>
# 123.44
# <class 'float'>
# False
# <class 'bool'>
# None
# <class 'NoneType'>

# %% [markdown]
# Q1.write a program to print your full name uisng variables

# %%
first_name="Walter"
last_name="White"
print("full name is:",first_name,last_name) #printing multiple character
# Out:
# full name is: Walter White

# %% [markdown]
# Multiple variable assignment:
# at a time assigning multiple values to a variable

# %%
#multiple variable assignment
a,b,c=12,32,54
print(a)
print(b)
print(c)
# Out:
# 12
# 32
# 54

# %% [markdown]
# Write a program to swap two numbers

# %%
method 1

# %%
a,b=10,20
print("the value of a is:",a)
print("the value of b is:",b)
a,b=b,a #here the value of a and b will be swapped #this method is called tuple unpacking
print("the value of a after swap",a)
print("the value of b after swap",b)
# Out:
# the value of a is: 10
# the value of b is: 20
# 10 20
# the value of a after swap 20
# the value of b after swap 10
# 20 10

# %%
method 2

# %%
a,b=10,20
print("the value of a:",a)
print("the value of b:",b)
a=a+b #arithemetic method
b=a-b
a=a-b
print("a value after swap",a)
print("b value after swap",b)
# Out:
# the value of a: 10
# the value of b: 20
# a value after swap 20
# b value after swap 10

# %%
a,b=20,10
print("the value of a:",a)
print("the value of b:",b)
a=a-b
b=b+a
print("a value after swap",a)
print("b value after swap",b)
# Out:
# the value of a: 20
# the value of b: 10
# a value after swap 10
# b value after swap 20
