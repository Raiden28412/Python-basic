# %% [markdown]
# <a href="https://colab.research.google.com/github/Raiden28412/Python-basic/blob/main/june_batch26day3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Short hand if**

# %%
#output 1 if condition else output 1
#used o check conditions
#first condition true then the first statement is executed otherwise the second statement is executed

a=10
print("high value") if a>5 else print("low value")

# %% [markdown]
# Q1.Write a program to read a number and check if it is odd or even

# %%
a=int(input("enter a number"))
print("the number is even") if a%2==0 else print("The number is odd")
# Out:
# enter a number17
# The number is odd

# %% [markdown]
# Q2.Write a program a number from user if the number is greater than 250 print hight profit or else low profit

# %%
a=int(input("enter a value for checking profit or loss"))
print("high profit")if a>250 else print("Low profit")
# Out:
# enter a value for checking profit or loss120
# Low profit

# %% [markdown]
# Q3.write a program to read a character from user if the character is vowel or not

# %%
character=input("Enter a character")
vowel="aeiouAEIOU"
print("it is a vowel")if(character in vowel) else print("not a vowel")
# Out:
# Enter a charactera
# it is a vowel

# %% [markdown]
# Q4.Write a program to read age from user minor if age less than 18 otherwise print adult

# %%
a=int(input("enter a age "))
print("minor")if a<18 else print("adult")
# Out:
# enter a age 44
# adult

# %% [markdown]
# F string method

# %%
name="dora"
age=13
#to print continous variables
print(f"age of {name} is {age}") #here it starts with f"statetemts {variables}"
# Out:
# age of dora is 13

# %% [markdown]
# Format method

# %%
name="dora"
age=13
#to print continous variables
print("age of {0} is {1}".format(name,age))#here the curly braces nothing is written and at the end .format(varible) is written
# Out:
# age of dora is 13

# %% [markdown]
# Operator Precedance

# %%
print(10+2*5) #operator precedence paraenthesis>exponential>multiplication>divison>addition>substraction

# %% [markdown]
# if the value of v is 3 then find v+v^2+v^3

# %%
v=int(input("enter the value of v"))
v=v+v**2+v**3
print(v)
# Out:
# enter the value of v5
# 155

# %%
write a program to find the sum of 10 natural numbers

# %%
n=10
sum=n*((n+1)/2)
print("sum of 10 naural number is ",sum)
# Out:
# sum of 10 naural number is  55.0

# %%
# Out:
# usermname:admin
# password:1234
# Login successful
